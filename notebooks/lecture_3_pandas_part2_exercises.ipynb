# %% [markdown]
# # Pandas Part 2 - Advanced Data Manipulation - Exercises
#
# This notebook contains exercises from Lecture 4: Pandas Part 2.
# Try to solve them yourself before looking at the solutions!

# %% [markdown]
# ## Part 1: File I/O - Reading CSV Files

# %% [markdown]
# ### ✏️ Challenge: Load and Inspect Sales Data
#
# **Problem:** Load the sales_data.csv file and:
# 1. Check how many rows and columns it has
# 2. Display the first 3 rows
# 3. Get basic information about the dataset
#
# **Hint:** Use `pd.read_csv()`, `.shape`, `.head()`, and `.columns`

# %%
# Your solution here
import pandas as pd
import os

# Get the data directory path
data_dir = os.path.join('..', 'data')
sales_file = os.path.join(data_dir, 'sales_data.csv')

# Load the CSV file
# Check shape (rows and columns)
# Display first 3 rows
# Get column names

# %% [markdown]
# ## Part 2: File I/O - Writing Data

# %% [markdown]
# ### ✏️ Challenge: Save Processed Data
#
# **Problem:** Create a summary DataFrame with metrics and save it to CSV
#
# Create a DataFrame with:
# - Metric column: ['Total Customers', 'Average Age', 'Total Sales']
# - Value column: [1000, 45.5, 50000]
#
# Then save it to a CSV file named 'summary.csv'

# %%
# Your solution here
import pandas as pd

# Create summary DataFrame
# Save to CSV file

# %% [markdown]
# ## Part 3: Data Cleaning - Handling Missing Data

# %% [markdown]
# ### ✏️ Challenge: Clean Customer Data
#
# **Problem:** The customer_data.csv has missing Age values.
# Fill them with the median age and show the result.
#
# **Steps:**
# 1. Load customer_data.csv
# 2. Check how many missing Age values exist
# 3. Calculate the median age
# 4. Fill missing ages with the median
# 5. Verify that all missing values are filled

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')

# Load customer data
# Check for missing Age values
# Calculate median age
# Fill missing values with median
# Verify the result

# %% [markdown]
# ## Part 4: Data Cleaning - Data Type Conversion

# %% [markdown]
# ### 📊 Real-World Case: Fix Data Types
#
# **Problem:** Date column is read as string. Convert it properly.
#
# Load customer_data.csv and convert the SignupDate column from string to datetime format.
#
# **Hint:** Use `pd.to_datetime()`

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')

# Load customer data
# Convert SignupDate to datetime
# Verify the conversion

# %% [markdown]
# ## Part 5: Data Cleaning - Removing Duplicates

# %% [markdown]
# ### ✏️ Challenge: Clean Duplicate Customers
#
# **Problem:** Remove duplicate customers based on CustomerID
#
# **Steps:**
# 1. Load customer_data.csv
# 2. Check for duplicate CustomerIDs
# 3. Remove duplicates keeping the first occurrence
# 4. Show how many unique customers remain

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')

# Load customer data
# Check for duplicates based on CustomerID
# Remove duplicates
# Show results

# %% [markdown]
# ## Part 6: Data Cleaning - String Operations

# %% [markdown]
# ### ✏️ Challenge: Extract City Codes
#
# **Problem:** Create a new column with first 3 letters of city name (uppercase)
#
# Load customer_data.csv and create a new column 'CityCode' that contains the first 3 letters of each city name in uppercase.
#
# **Hint:** Use `.str[:3]` and `.str.upper()`

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')

# Load customer data
# Create CityCode column with first 3 letters (uppercase)
# Display results

# %% [markdown]
# ## Part 7: Advanced Operations - Merging DataFrames

# %% [markdown]
# ### 📊 Real-World Case: Combine Customer and Sales Data
#
# **Problem:** Merge customer information with their sales records
#
# **Steps:**
# 1. Load customer_data.csv and sales_data.csv
# 2. Merge them on CustomerID using inner join
# 3. Show how many rows are in the merged dataset
# 4. Display the first few rows of the merged data
#
# **Hint:** Use `pd.merge()` with `on='CustomerID'` and `how='inner'`

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')
sales_file = os.path.join(data_dir, 'sales_data.csv')

# Load both datasets
# Merge on CustomerID
# Show results

# %% [markdown]
# ## Part 8: Advanced Operations - Pivot Tables

# %% [markdown]
# ### ✏️ Challenge: Sales Analysis Pivot Table
#
# **Problem:** Create a pivot table showing:
# - Rows: Product
# - Columns: Region
# - Values: Average Sales
# - Fill NaN values with 0
#
# **Steps:**
# 1. Load sales_data.csv
# 2. Clean data (remove rows with missing Sales)
# 3. Create pivot table with the specified structure
# 4. Display the result
#
# **Hint:** Use `pd.pivot_table()` with `aggfunc='mean'` and `fill_value=0`

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
sales_file = os.path.join(data_dir, 'sales_data.csv')

# Load sales data
# Clean data (remove missing Sales)
# Create pivot table
# Display result

# %% [markdown]
# ## Part 9: Advanced Operations - Time Series

# %% [markdown]
# ### 📊 Real-World Case: Weather Time Series Analysis
#
# **Problem:** Analyze weather data to find average temperature by month and city
#
# **Steps:**
# 1. Load weather_data.csv
# 2. Convert Date column to datetime
# 3. Set Date as index
# 4. Group by month and city to calculate average temperature
# 5. Create a pivot table showing average temperature by month (rows) and city (columns)
#
# **Hint:** Use `.to_period('M')` for monthly grouping and `.pivot()` for reshaping

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
weather_file = os.path.join(data_dir, 'weather_data.csv')

# Load weather data
# Convert Date to datetime
# Set Date as index
# Group by month and city
# Create pivot table
# Display results

# %% [markdown]
# ## Part 10: Advanced Operations - Apply Functions

# %% [markdown]
# ### ✏️ Challenge: Customer Segmentation
#
# **Problem:** Create customer segments based on TotalSpent:
# - 'VIP': > 4000
# - 'Regular': 2000-4000
# - 'New': < 2000
#
# **Steps:**
# 1. Load customer_data.csv
# 2. Create a function to categorize customers
# 3. Apply the function to create a 'Segment' column
# 4. Count customers in each segment
#
# **Hint:** Use `.apply()` with a custom function

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
customer_file = os.path.join(data_dir, 'customer_data.csv')

# Load customer data
# Define segmentation function
# Apply function to create Segment column
# Count segments
# Display results

# %% [markdown]
# ## 🎓 Project 1: Complete Data Cleaning Pipeline

# %% [markdown]
# ### Complete Data Cleaning Pipeline
#
# **Problem:** Clean a messy dataset with:
# - Missing values
# - Incorrect data types
# - Duplicates
# - Inconsistent formatting
#
# **Steps:**
# 1. Load sales_data.csv
# 2. Inspect data (check missing values, data types)
# 3. Fix data types (Date, Sales, Quantity)
# 4. Handle missing values (fill with appropriate values)
# 5. Remove duplicates
# 6. Final check (verify no missing values remain)
#
# **Your Task:** Implement each step and show the results

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
sales_file = os.path.join(data_dir, 'sales_data.csv')

# Step 1: Load Data
# Step 2: Inspect Data
# Step 3: Fix Data Types
# Step 4: Handle Missing Values
# Step 5: Remove Duplicates
# Step 6: Final Check

# %% [markdown]
# ## 🎓 Project 2: Comprehensive Sales Analysis

# %% [markdown]
# ### Comprehensive Sales Analysis
#
# **Problem:** Analyze e-commerce transaction data to answer business questions:
#
# 1. Total revenue by product category
# 2. Best performing region
# 3. Monthly sales trends
# 4. Top customers by spending
# 5. Payment method analysis
#
# **Steps:**
# 1. Load ecommerce_transactions.csv and customer_demographics.csv
# 2. Clean and prepare data
# 3. Calculate revenue by category
# 4. Find best performing region
# 5. Analyze monthly trends
# 6. Identify top customers
# 7. Analyze payment methods
# 8. Create executive summary
#
# **Your Task:** Implement the analysis and provide insights

# %%
# Your solution here
import pandas as pd
import os

data_dir = os.path.join('..', 'data')
ecommerce_file = os.path.join(data_dir, 'ecommerce_transactions.csv')
customer_file = os.path.join(data_dir, 'customer_demographics.csv')

# Step 1: Load and Prepare Data
# Step 2: Revenue by Product Category
# Step 3: Best Performing Region
# Step 4: Monthly Sales Trends
# Step 5: Top Customers by Spending
# Step 6: Payment Method Analysis
# Step 7: Merge with Customer Demographics
# Step 8: Summary Statistics
